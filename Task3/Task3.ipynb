# %% [markdown]
# # Task 3

# %%
print("write no of input you want")
val = input("Enter number")
print(val)
alluser = {}
print("enter the name:age in input field")
for i in range(int(val)):
    key_value = input("enter value " + str(i+1)+ " = ")
    results  = key_value.split(":")
    alluser[results[0]] = int(results[1])

age_group = {
"Range_18to35" : [],
"Range_36to50" : [],
"Range_51to65" : [],
"Range_66to90" : []
}
for name,age in alluser.items():
    if 18 <= age <= 35:
        age_group["Range_18to35"].append((name,age))
    elif 36 <= age <= 50:
        age_group["Range_36to50"].append((name,age))
    elif 51 <= age <= 65:
        age_group["Range_51to65"].append((name,age))
    elif 66 <= age <= 90:
        age_group["Range_66to90"].append((name,age))

def find_oldest_youngest(group):
    if group:
        oldest = max(group, key=lambda x: x[i])
        youngest = min(group, key=lambda x: x[1])
        return oldest, youngest
    return None, None

for group, people in age_group.items():
    oldest, youngest = find_oldest_youngest(people)
    print("Age Group " + group)
    if oldest and youngest:
        print(f"oldest = {oldest} and youngest = {youngest}")
# Out:
# write no of input you want
# Enter number1
# 1
# enter the name:age in input field
# enter value 1 = Kishan:34
# Age Group Range_18to35
# oldest = ('Kishan', 34) and youngest = ('Kishan', 34)
# Age Group Range_36to50
# Age Group Range_51to65
# Age Group Range_66to90
